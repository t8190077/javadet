# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
headers = ['Names','ID','AMKA','DOB','EMAIL','PHONE','AMKACHAIN']
patientsnetwork = pd.read_csv('data.txt', names = headers)
patientsnetwork = patientsnetwork.astype(str)
patientsnetwork['AMKACHAIN']=patientsnetwork['AMKACHAIN'].apply(lambda x: x.split(" "))

patientsnetwork
# Out:
#                   Names     ID    AMKA        DOB              EMAIL  \
# 0                 ferdi      1       2          w                  w
# 1                    jo      2       3          w                  w
# 2                  pied      3       4          w                  w
# 3                 piper      4       5          w                  w
# 4                 hooli      5       6          w                  w
# 5                    yo      6       7          r                  r
# 6                   wer     10      11          w                  w
# 7                   qwe     11      12          w                  e
# 8                   sdf     12      13          w                  w
# 9                   sdf     13      14          w                  w
# 10                  wer     14      15          r                  r
# 11                  ert     15      16          t                  t
# 12               qweqwe  12312  123123     123123             qweqwe
# 13                qweqe  12123  123123     123123             123123
# 14               Johnny     19      24     123123              errer
# 15               Joanna     19     123  123121231              wqewe
# 16              Errikos     20  123123     123123             qweqwe
# 17                 Chet     18   23423   09/09/10       ok@gmail.com
# 18             Testname     20      20   08/08/99       test@test.gr
# 19             Testname     22      22   08/08/99       test@test.gr
# 20             Testname     24      24   08/08/99       test@test.gr
# 21             Testname     26      26   08/08/99       test@test.gr
# 22             Testname     28      28   08/08/99       test@test.gr
# 23  Sokratis Koumpardas     28      30   30/30/99       ok@gmail.com
# 24  Socrates Koumpardas     29  918324   06/06/99  koump@hotmail.com
# 25  Michalis Eustathiou     25      30   08/08/97     mich@gmail.com
# 26  Michalis Eustathiou     26      35   08/08/97     mich@gmail.com
#
#              PHONE         AMKACHAIN
# 0                w               [1]
# 1                w            [1, 2]
# 2                w            [1, 3]
# 3                w               [5]
# 4                w               [2]
# 5                r               [5]
# 6                w               [2]
# 7                w              [11]
# 8                w              [11]
# 9                w           [11, 9]
# 10               r              [15]
# 11               t              [16]
# 12          123213          [13, 15]
# 13           12313             [123]
# 14          213213     [6, 8, 9, 10]
# 15             qwe         [1, 3, 4]
# 16         wqweqwe       [1, 3, 4, ]
# 17         1230239       [12, 14, 9]
# 18       210999999      [12, 13, 19]
# 19       210999999       [8, 10, 19]
# 20       210999999              [23]
# 21       210999999               [9]
# 22       210999999  [26, 27, 123123]
# 23        21099999              [16]
# 24      2109696586   [1, 2, 3, 4, 5]
# 25  21039847309483       [1, 3, 5, ]
# 26  21039847309483       [1, 3, 5, ]

# %%
import networkx as nx

adj = patientsnetwork['AMKACHAIN'].tolist()

# %%
names = patientsnetwork['AMKA'].tolist()

names
# Out:
# ['2',
#  '3',
#  '4',
#  '5',
#  '6',
#  '7',
#  '11',
#  '12',
#  '13',
#  '14',
#  '15',
#  '16',
#  '123123',
#  '123123',
#  '24',
#  '123',
#  '123123',
#  '23423',
#  '20',
#  '22',
#  '24',
#  '26',
#  '28',
#  '30',
#  '918324',
#  '30',
#  '35']

# %%
dictt = {}
dictt = dict(zip(names,adj))
dictt
# Out:
# {'2': ['1'],
#  '3': ['1', '2'],
#  '4': ['1', '3'],
#  '5': ['5'],
#  '6': ['2'],
#  '7': ['5'],
#  '11': ['2'],
#  '12': ['11'],
#  '13': ['11'],
#  '14': ['11', '9'],
#  '15': ['15'],
#  '16': ['16'],
#  '123123': ['1', '3', '4', ''],
#  '24': ['23'],
#  '123': ['1', '3', '4'],
#  '23423': ['12', '14', '9'],
#  '20': ['12', '13', '19'],
#  '22': ['8', '10', '19'],
#  '26': ['9'],
#  '28': ['26', '27', '123123'],
#  '30': ['1', '3', '5', ''],
#  '918324': ['1', '2', '3', '4', '5'],
#  '35': ['1', '3', '5', '']}

# %%
G = nx.Graph(dictt)
pos=nx.spring_layout(G)
list(G)
# Out:
# ['2',
#  '3',
#  '4',
#  '5',
#  '6',
#  '7',
#  '11',
#  '12',
#  '13',
#  '14',
#  '15',
#  '16',
#  '123123',
#  '24',
#  '123',
#  '23423',
#  '20',
#  '22',
#  '26',
#  '28',
#  '30',
#  '918324',
#  '35',
#  '1',
#  '9',
#  '',
#  '23',
#  '19',
#  '8',
#  '10',
#  '27']

# %%
plt.figure(figsize=(14,14))

nx.draw(G, with_labels=True, node_size=1000, node_color="skyblue", node_shape="s", alpha=0.5, linewidths=50)

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
